# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras.callbacks import Callback

# %%
# Function to load the dataset
def load_monk_data(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            if line.strip():  # Ignore empty lines
                parts = line.strip().split()  # Split by spaces
                target = int(parts[0])  # First column is the target
                features = list(map(int, parts[1:7]))  # Next six columns are features
                data.append([target] + features)
    return np.array(data)

# Load train and test datasets
train_data = load_monk_data("monks-1.train")
test_data = load_monk_data("monks-1.test")

# Extract features and target
X_train = train_data[:, 1:]
y_train = train_data[:, 0]
X_test = test_data[:, 1:]
y_test = test_data[:, 0]

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Funzione di attivazione RBF con TensorFlow
def rbf_activation(x, centers, gamma=1.0):
    # Calcola la distanza euclidea tra l'input e i centri
    diff = x[:, np.newaxis, :] - centers
    dist_sq = tf.reduce_sum(tf.square(diff), axis=-1)  # Usa tf.reduce_sum invece di np.sum
    return tf.exp(-gamma * dist_sq)

# Creare il modello
def build_rbf_model(input_dim, output_dim, n_centers, gamma, learning_rate):
    model = models.Sequential()

    # Layer di input: utilizza 'shape' invece di 'input_dim'
    model.add(layers.InputLayer(shape=(input_dim,)))

    # Layer nascosta con attivazione RBF (calcola distanza dal centro)
    centers = tf.Variable(np.random.randn(n_centers, input_dim), dtype=tf.float32)  # Centri randomici
    model.add(layers.Lambda(lambda x: rbf_activation(x, centers, gamma)))

    # Layer di output con una dimensione pari al numero di target (3 in questo caso: x, y, z)
    model.add(layers.Dense(output_dim))

    # Optimizer
    optimizer = Adam(learning_rate=learning_rate)

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mse', 'accuracy'])

    return model

# Custom callback to track test metrics at each epoch
class TestMetricsCallback(Callback):
    def __init__(self, test_data):
        self.test_data = test_data
        self.test_accuracy = []
        self.test_mse = []

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc, test_mse = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        self.test_accuracy.append(test_acc)
        self.test_mse.append(test_mse)

# %%
# Parametri fissi
input_dim = 6
output_dim = 1

n_centers = 120 #Lower value more flat
gamma = 0.17 #Higher value more flat - Lower value lower val_loss
batch_size = 20 #Higher more flat - low value low test_loss
learning_rate = 0.004 #Lower value more flat - high value flatline - high value low test_loss high val_loss

# Creazione del modello
rbf_model = build_rbf_model(input_dim, output_dim, n_centers, gamma, learning_rate)

# Instantiate the callback
test_metrics_callback = TestMetricsCallback((X_test, y_test))

# Addestramento del modello
history = rbf_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=batch_size,
    validation_data=(X_val, y_val),
    callbacks=[test_metrics_callback]
)

# Plot training and test accuracy
plt.figure(figsize=(5, 3))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(test_metrics_callback.test_accuracy, linestyle='dotted', label='Test Accuracy')
plt.title('Training and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and test MSE
plt.figure(figsize=(5, 3))
plt.plot(history.history['mse'], label='Training MSE')
plt.plot(test_metrics_callback.test_mse, linestyle='dotted', label='Test MSE')
plt.title('Training and Test MSE')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

tr_accuracy = min(history.history['accuracy'])
ts_accuracy = min(history.history['val_acc'])
tr_mse = min(history.history['mse'])
ts_mse = min(history.history['val_mse'])
print(f"Training Accuracy: {tr_accuracy}")
print(f"Validation Accuracy: {val_accuracy}")
print(f"Training MSE: {tr_mse}")
print(f"Validation MSE: {val_mse}")
# Out:
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4624 - loss: 0.5496 - mse: 0.5496 - val_accuracy: 0.6000 - val_loss: 0.3528 - val_mse: 0.3528
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5166 - loss: 0.4260 - mse: 0.4260 - val_accuracy: 0.6000 - val_loss: 0.2964 - val_mse: 0.2964
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4846 - loss: 0.4008 - mse: 0.4008 - val_accuracy: 0.6800 - val_loss: 0.2611 - val_mse: 0.2611
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5108 - loss: 0.3331 - mse: 0.3331 - val_accuracy: 0.6800 - val_loss: 0.2463 - val_mse: 0.2463
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5921 - loss: 0.3074 - mse: 0.3074 - val_accuracy: 0.5600 - val_loss: 0.2477 - val_mse: 0.2477
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5602 - loss: 0.2877 - mse: 0.2877 - val_accuracy: 0.6000 - val_loss: 0.2596 - val_mse: 0.2596
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6078 - loss: 0.2675 - mse: 0.2675 - val_accuracy: 0.6000 - val_loss: 0.2766 - val_mse: 0.2766
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5587 - loss: 0.2713 - mse: 0.2713 - val_accuracy: 0.6000 - val_loss: 0.2938 - val_mse: 0.2938
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5983 - loss: 0.2484 - mse: 0.2484 - val_accuracy: 0.6800 - val_loss: 0.3086 - val_mse: 0.3086
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5426 - loss: 0.2768 - mse: 0.2768 - val_accuracy: 0.6800 - val_loss: 0.3179 - val_mse: 0.3179
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5509 - loss: 0.2676 - mse: 0.2676 - val_accuracy: 0.6800 - val_loss: 0.3206 - val_mse: 0.3206
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5511 - loss: 0.2580 - mse: 0.2580 - val_accuracy: 0.6800 - val_loss: 0.3196 - val_mse: 0.3196
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5490 - loss: 0.2493 - mse: 0.2493 - val_accuracy: 0.6800 - val_loss: 0.3145 - val_mse: 0.3145
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5469 - loss: 0.2650 - mse: 0.2650 - val_accuracy: 0.6800 - val_loss: 0.3086 - val_mse: 0.3086
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5691 - loss: 0.2584 - mse: 0.2584 - val_accuracy: 0.6800 - val_loss: 0.2998 - val_mse: 0.2998
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5823 - loss: 0.2539 - mse: 0.2539 - val_accuracy: 0.6800 - val_loss: 0.2919 - val_mse: 0.2919
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5537 - loss: 0.2645 - mse: 0.2645 - val_accuracy: 0.6800 - val_loss: 0.2871 - val_mse: 0.2871
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6100 - loss: 0.2356 - mse: 0.2356 - val_accuracy: 0.6800 - val_loss: 0.2821 - val_mse: 0.2821
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5808 - loss: 0.2436 - mse: 0.2436 - val_accuracy: 0.6800 - val_loss: 0.2756 - val_mse: 0.2756
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6253 - loss: 0.2225 - mse: 0.2225 - val_accuracy: 0.6800 - val_loss: 0.2718 - val_mse: 0.2718
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6253 - loss: 0.2241 - mse: 0.2241 - val_accuracy: 0.6800 - val_loss: 0.2655 - val_mse: 0.2655
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5579 - loss: 0.2427 - mse: 0.2427 - val_accuracy: 0.6800 - val_loss: 0.2619 - val_mse: 0.2619
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5718 - loss: 0.2445 - mse: 0.2445 - val_accuracy: 0.6800 - val_loss: 0.2594 - val_mse: 0.2594
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6008 - loss: 0.2319 - mse: 0.2319 - val_accuracy: 0.6800 - val_loss: 0.2582 - val_mse: 0.2582
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5592 - loss: 0.2500 - mse: 0.2500 - val_accuracy: 0.6800 - val_loss: 0.2563 - val_mse: 0.2563
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4932 - loss: 0.2566 - mse: 0.2566 - val_accuracy: 0.6800 - val_loss: 0.2541 - val_mse: 0.2541
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5432 - loss: 0.2400 - mse: 0.2400 - val_accuracy: 0.7200 - val_loss: 0.2503 - val_mse: 0.2503
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6113 - loss: 0.2165 - mse: 0.2165 - val_accuracy: 0.7200 - val_loss: 0.2478 - val_mse: 0.2478
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5402 - loss: 0.2427 - mse: 0.2427 - val_accuracy: 0.7200 - val_loss: 0.2484 - val_mse: 0.2484
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6270 - loss: 0.2216 - mse: 0.2216 - val_accuracy: 0.7200 - val_loss: 0.2449 - val_mse: 0.2449
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5575 - loss: 0.2431 - mse: 0.2431 - val_accuracy: 0.7200 - val_loss: 0.2409 - val_mse: 0.2409
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6693 - loss: 0.2199 - mse: 0.2199 - val_accuracy: 0.7200 - val_loss: 0.2391 - val_mse: 0.2391
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6678 - loss: 0.2119 - mse: 0.2119 - val_accuracy: 0.7200 - val_loss: 0.2369 - val_mse: 0.2369
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6317 - loss: 0.2215 - mse: 0.2215 - val_accuracy: 0.7200 - val_loss: 0.2346 - val_mse: 0.2346
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6164 - loss: 0.2287 - mse: 0.2287 - val_accuracy: 0.7200 - val_loss: 0.2315 - val_mse: 0.2315
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6253 - loss: 0.2259 - mse: 0.2259 - val_accuracy: 0.7200 - val_loss: 0.2329 - val_mse: 0.2329
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6245 - loss: 0.2238 - mse: 0.2238 - val_accuracy: 0.7200 - val_loss: 0.2302 - val_mse: 0.2302
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6433 - loss: 0.2160 - mse: 0.2160 - val_accuracy: 0.7200 - val_loss: 0.2289 - val_mse: 0.2289
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6217 - loss: 0.2195 - mse: 0.2195 - val_accuracy: 0.7200 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6599 - loss: 0.2185 - mse: 0.2185 - val_accuracy: 0.7200 - val_loss: 0.2249 - val_mse: 0.2249
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6857 - loss: 0.2038 - mse: 0.2038 - val_accuracy: 0.7200 - val_loss: 0.2254 - val_mse: 0.2254
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6185 - loss: 0.2159 - mse: 0.2159 - val_accuracy: 0.7200 - val_loss: 0.2248 - val_mse: 0.2248
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6357 - loss: 0.2170 - mse: 0.2170 - val_accuracy: 0.7200 - val_loss: 0.2220 - val_mse: 0.2220
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6620 - loss: 0.2138 - mse: 0.2138 - val_accuracy: 0.7200 - val_loss: 0.2219 - val_mse: 0.2219
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6495 - loss: 0.2128 - mse: 0.2128 - val_accuracy: 0.7200 - val_loss: 0.2209 - val_mse: 0.2209
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6816 - loss: 0.2012 - mse: 0.2012 - val_accuracy: 0.7200 - val_loss: 0.2204 - val_mse: 0.2204
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6246 - loss: 0.2152 - mse: 0.2152 - val_accuracy: 0.7200 - val_loss: 0.2185 - val_mse: 0.2185
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6626 - loss: 0.2076 - mse: 0.2076 - val_accuracy: 0.7600 - val_loss: 0.2166 - val_mse: 0.2166
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6425 - loss: 0.2164 - mse: 0.2164 - val_accuracy: 0.7200 - val_loss: 0.2155 - val_mse: 0.2155
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6230 - loss: 0.2210 - mse: 0.2210 - val_accuracy: 0.7200 - val_loss: 0.2147 - val_mse: 0.2147
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6404 - loss: 0.2115 - mse: 0.2115 - val_accuracy: 0.7200 - val_loss: 0.2151 - val_mse: 0.2151
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6618 - loss: 0.2129 - mse: 0.2129 - val_accuracy: 0.6800 - val_loss: 0.2155 - val_mse: 0.2155
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6847 - loss: 0.2052 - mse: 0.2052 - val_accuracy: 0.6800 - val_loss: 0.2145 - val_mse: 0.2145
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7013 - loss: 0.2028 - mse: 0.2028 - val_accuracy: 0.7200 - val_loss: 0.2119 - val_mse: 0.2119
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6763 - loss: 0.2120 - mse: 0.2120 - val_accuracy: 0.6800 - val_loss: 0.2119 - val_mse: 0.2119
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6859 - loss: 0.2118 - mse: 0.2118 - val_accuracy: 0.6800 - val_loss: 0.2123 - val_mse: 0.2123
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6734 - loss: 0.2076 - mse: 0.2076 - val_accuracy: 0.6800 - val_loss: 0.2115 - val_mse: 0.2115
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7206 - loss: 0.2013 - mse: 0.2013 - val_accuracy: 0.6800 - val_loss: 0.2102 - val_mse: 0.2102
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6970 - loss: 0.2107 - mse: 0.2107 - val_accuracy: 0.6800 - val_loss: 0.2096 - val_mse: 0.2096
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6754 - loss: 0.2122 - mse: 0.2122 - val_accuracy: 0.6800 - val_loss: 0.2099 - val_mse: 0.2099
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7394 - loss: 0.1974 - mse: 0.1974 - val_accuracy: 0.6800 - val_loss: 0.2102 - val_mse: 0.2102
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7366 - loss: 0.1999 - mse: 0.1999 - val_accuracy: 0.6800 - val_loss: 0.2096 - val_mse: 0.2096
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6817 - loss: 0.2111 - mse: 0.2111 - val_accuracy: 0.6800 - val_loss: 0.2103 - val_mse: 0.2103
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7345 - loss: 0.2016 - mse: 0.2016 - val_accuracy: 0.6800 - val_loss: 0.2100 - val_mse: 0.2100
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7262 - loss: 0.2038 - mse: 0.2038 - val_accuracy: 0.6800 - val_loss: 0.2088 - val_mse: 0.2088
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6899 - loss: 0.2097 - mse: 0.2097 - val_accuracy: 0.6800 - val_loss: 0.2078 - val_mse: 0.2078
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7440 - loss: 0.1988 - mse: 0.1988 - val_accuracy: 0.6800 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7072 - loss: 0.2013 - mse: 0.2013 - val_accuracy: 0.6800 - val_loss: 0.2088 - val_mse: 0.2088
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6927 - loss: 0.2093 - mse: 0.2093 - val_accuracy: 0.6800 - val_loss: 0.2095 - val_mse: 0.2095
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6914 - loss: 0.2050 - mse: 0.2050 - val_accuracy: 0.6800 - val_loss: 0.2085 - val_mse: 0.2085
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7274 - loss: 0.1954 - mse: 0.1954 - val_accuracy: 0.6800 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7100 - loss: 0.2081 - mse: 0.2081 - val_accuracy: 0.6800 - val_loss: 0.2074 - val_mse: 0.2074
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7593 - loss: 0.1901 - mse: 0.1901 - val_accuracy: 0.6800 - val_loss: 0.2067 - val_mse: 0.2067
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6871 - loss: 0.2006 - mse: 0.2006 - val_accuracy: 0.6800 - val_loss: 0.2062 - val_mse: 0.2062
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6412 - loss: 0.2117 - mse: 0.2117 - val_accuracy: 0.6800 - val_loss: 0.2079 - val_mse: 0.2079
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6289 - loss: 0.2111 - mse: 0.2111 - val_accuracy: 0.6800 - val_loss: 0.2074 - val_mse: 0.2074
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7275 - loss: 0.1998 - mse: 0.1998 - val_accuracy: 0.6800 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6414 - loss: 0.2088 - mse: 0.2088 - val_accuracy: 0.6800 - val_loss: 0.2080 - val_mse: 0.2080
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6587 - loss: 0.2042 - mse: 0.2042 - val_accuracy: 0.6800 - val_loss: 0.2062 - val_mse: 0.2062
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6787 - loss: 0.2017 - mse: 0.2017 - val_accuracy: 0.6800 - val_loss: 0.2072 - val_mse: 0.2072
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6872 - loss: 0.2002 - mse: 0.2002 - val_accuracy: 0.6800 - val_loss: 0.2072 - val_mse: 0.2072
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6747 - loss: 0.2055 - mse: 0.2055 - val_accuracy: 0.6800 - val_loss: 0.2063 - val_mse: 0.2063
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7240 - loss: 0.1925 - mse: 0.1925 - val_accuracy: 0.6800 - val_loss: 0.2054 - val_mse: 0.2054
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6857 - loss: 0.2089 - mse: 0.2089 - val_accuracy: 0.6800 - val_loss: 0.2058 - val_mse: 0.2058
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6518 - loss: 0.2106 - mse: 0.2106 - val_accuracy: 0.6800 - val_loss: 0.2049 - val_mse: 0.2049
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7268 - loss: 0.1930 - mse: 0.1930 - val_accuracy: 0.6800 - val_loss: 0.2056 - val_mse: 0.2056
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7406 - loss: 0.1894 - mse: 0.1894 - val_accuracy: 0.6800 - val_loss: 0.2046 - val_mse: 0.2046
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7253 - loss: 0.1936 - mse: 0.1936 - val_accuracy: 0.6800 - val_loss: 0.2037 - val_mse: 0.2037
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7114 - loss: 0.1996 - mse: 0.1996 - val_accuracy: 0.6800 - val_loss: 0.2060 - val_mse: 0.2060
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6914 - loss: 0.1966 - mse: 0.1966 - val_accuracy: 0.6800 - val_loss: 0.2054 - val_mse: 0.2054
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6677 - loss: 0.1951 - mse: 0.1951 - val_accuracy: 0.6800 - val_loss: 0.2057 - val_mse: 0.2057
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7072 - loss: 0.1978 - mse: 0.1978 - val_accuracy: 0.6800 - val_loss: 0.2073 - val_mse: 0.2073
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6989 - loss: 0.2030 - mse: 0.2030 - val_accuracy: 0.6800 - val_loss: 0.2050 - val_mse: 0.2050
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6704 - loss: 0.2039 - mse: 0.2039 - val_accuracy: 0.6800 - val_loss: 0.2063 - val_mse: 0.2063
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7551 - loss: 0.1872 - mse: 0.1872 - val_accuracy: 0.6800 - val_loss: 0.2046 - val_mse: 0.2046
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6496 - loss: 0.2095 - mse: 0.2095 - val_accuracy: 0.6800 - val_loss: 0.2047 - val_mse: 0.2047
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7190 - loss: 0.2019 - mse: 0.2019 - val_accuracy: 0.6800 - val_loss: 0.2057 - val_mse: 0.2057
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6822 - loss: 0.2019 - mse: 0.2019 - val_accuracy: 0.6800 - val_loss: 0.2051 - val_mse: 0.2051
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6947 - loss: 0.2050 - mse: 0.2050 - val_accuracy: 0.6800 - val_loss: 0.2044 - val_mse: 0.2044
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7349 - loss: 0.1918 - mse: 0.1918 - val_accuracy: 0.6800 - val_loss: 0.2040 - val_mse: 0.2040
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7259 - loss: 0.2048 - mse: 0.2048 - val_accuracy: 0.6800 - val_loss: 0.2050 - val_mse: 0.2050
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6760 - loss: 0.2009 - mse: 0.2009 - val_accuracy: 0.6800 - val_loss: 0.2055 - val_mse: 0.2055
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6849 - loss: 0.2032 - mse: 0.2032 - val_accuracy: 0.6800 - val_loss: 0.2051 - val_mse: 0.2051
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7438 - loss: 0.1916 - mse: 0.1916 - val_accuracy: 0.6800 - val_loss: 0.2036 - val_mse: 0.2036
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7210 - loss: 0.2028 - mse: 0.2028 - val_accuracy: 0.6800 - val_loss: 0.2037 - val_mse: 0.2037
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7258 - loss: 0.2026 - mse: 0.2026 - val_accuracy: 0.6800 - val_loss: 0.2049 - val_mse: 0.2049
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7349 - loss: 0.2072 - mse: 0.2072 - val_accuracy: 0.6800 - val_loss: 0.2031 - val_mse: 0.2031
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7335 - loss: 0.1913 - mse: 0.1913 - val_accuracy: 0.6800 - val_loss: 0.2042 - val_mse: 0.2042
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7252 - loss: 0.1940 - mse: 0.1940 - val_accuracy: 0.6800 - val_loss: 0.2034 - val_mse: 0.2034
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7085 - loss: 0.2004 - mse: 0.2004 - val_accuracy: 0.6800 - val_loss: 0.2035 - val_mse: 0.2035
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6849 - loss: 0.2005 - mse: 0.2005 - val_accuracy: 0.7200 - val_loss: 0.2028 - val_mse: 0.2028
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7481 - loss: 0.1998 - mse: 0.1998 - val_accuracy: 0.6800 - val_loss: 0.2034 - val_mse: 0.2034
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6974 - loss: 0.2089 - mse: 0.2089 - val_accuracy: 0.7200 - val_loss: 0.2027 - val_mse: 0.2027
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6779 - loss: 0.2050 - mse: 0.2050 - val_accuracy: 0.6800 - val_loss: 0.2035 - val_mse: 0.2035
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7445 - loss: 0.1960 - mse: 0.1960 - val_accuracy: 0.7200 - val_loss: 0.2035 - val_mse: 0.2035
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7563 - loss: 0.1910 - mse: 0.1910 - val_accuracy: 0.7200 - val_loss: 0.2039 - val_mse: 0.2039
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6862 - loss: 0.2072 - mse: 0.2072 - val_accuracy: 0.7200 - val_loss: 0.2043 - val_mse: 0.2043
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7535 - loss: 0.1930 - mse: 0.1930 - val_accuracy: 0.7200 - val_loss: 0.2044 - val_mse: 0.2044
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7348 - loss: 0.1938 - mse: 0.1938 - val_accuracy: 0.7200 - val_loss: 0.2037 - val_mse: 0.2037
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7417 - loss: 0.1937 - mse: 0.1937 - val_accuracy: 0.7600 - val_loss: 0.2026 - val_mse: 0.2026
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7002 - loss: 0.1986 - mse: 0.1986 - val_accuracy: 0.7600 - val_loss: 0.2022 - val_mse: 0.2022
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6946 - loss: 0.2046 - mse: 0.2046 - val_accuracy: 0.7600 - val_loss: 0.2015 - val_mse: 0.2015
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6828 - loss: 0.2017 - mse: 0.2017 - val_accuracy: 0.7600 - val_loss: 0.2022 - val_mse: 0.2022
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7035 - loss: 0.2011 - mse: 0.2011 - val_accuracy: 0.7600 - val_loss: 0.2016 - val_mse: 0.2016
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6973 - loss: 0.2067 - mse: 0.2067 - val_accuracy: 0.7600 - val_loss: 0.2018 - val_mse: 0.2018
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7417 - loss: 0.1985 - mse: 0.1985 - val_accuracy: 0.7600 - val_loss: 0.2019 - val_mse: 0.2019
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7500 - loss: 0.1960 - mse: 0.1960 - val_accuracy: 0.7600 - val_loss: 0.2025 - val_mse: 0.2025
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7507 - loss: 0.1861 - mse: 0.1861 - val_accuracy: 0.7600 - val_loss: 0.2023 - val_mse: 0.2023
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7541 - loss: 0.1957 - mse: 0.1957 - val_accuracy: 0.7600 - val_loss: 0.2023 - val_mse: 0.2023
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7215 - loss: 0.1976 - mse: 0.1976 - val_accuracy: 0.7600 - val_loss: 0.2019 - val_mse: 0.2019
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6882 - loss: 0.2046 - mse: 0.2046 - val_accuracy: 0.7600 - val_loss: 0.2030 - val_mse: 0.2030
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7215 - loss: 0.1880 - mse: 0.1880 - val_accuracy: 0.7600 - val_loss: 0.2028 - val_mse: 0.2028
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6909 - loss: 0.2002 - mse: 0.2002 - val_accuracy: 0.7600 - val_loss: 0.2018 - val_mse: 0.2018
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7395 - loss: 0.1956 - mse: 0.1956 - val_accuracy: 0.7600 - val_loss: 0.2022 - val_mse: 0.2022
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7270 - loss: 0.1961 - mse: 0.1961 - val_accuracy: 0.7600 - val_loss: 0.2014 - val_mse: 0.2014
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7388 - loss: 0.1927 - mse: 0.1927 - val_accuracy: 0.7600 - val_loss: 0.2018 - val_mse: 0.2018
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7493 - loss: 0.1909 - mse: 0.1909 - val_accuracy: 0.7600 - val_loss: 0.2019 - val_mse: 0.2019
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7416 - loss: 0.1896 - mse: 0.1896 - val_accuracy: 0.7600 - val_loss: 0.2013 - val_mse: 0.2013
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7458 - loss: 0.1877 - mse: 0.1877 - val_accuracy: 0.7600 - val_loss: 0.2006 - val_mse: 0.2006
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7000 - loss: 0.2046 - mse: 0.2046 - val_accuracy: 0.7600 - val_loss: 0.2014 - val_mse: 0.2014
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7375 - loss: 0.1893 - mse: 0.1893 - val_accuracy: 0.7600 - val_loss: 0.2016 - val_mse: 0.2016
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7402 - loss: 0.1908 - mse: 0.1908 - val_accuracy: 0.7600 - val_loss: 0.2016 - val_mse: 0.2016
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7437 - loss: 0.1948 - mse: 0.1948 - val_accuracy: 0.7600 - val_loss: 0.2005 - val_mse: 0.2005
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7062 - loss: 0.2009 - mse: 0.2009 - val_accuracy: 0.7600 - val_loss: 0.2005 - val_mse: 0.2005
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7340 - loss: 0.2028 - mse: 0.2028 - val_accuracy: 0.8000 - val_loss: 0.1996 - val_mse: 0.1996
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6994 - loss: 0.2033 - mse: 0.2033 - val_accuracy: 0.8000 - val_loss: 0.1994 - val_mse: 0.1994
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7515 - loss: 0.1906 - mse: 0.1906 - val_accuracy: 0.7600 - val_loss: 0.1995 - val_mse: 0.1995
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6806 - loss: 0.2022 - mse: 0.2022 - val_accuracy: 0.8000 - val_loss: 0.1995 - val_mse: 0.1995
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7334 - loss: 0.1847 - mse: 0.1847 - val_accuracy: 0.7600 - val_loss: 0.2010 - val_mse: 0.2010
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7895 - loss: 0.1844 - mse: 0.1844 - val_accuracy: 0.7600 - val_loss: 0.2009 - val_mse: 0.2009
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7569 - loss: 0.1841 - mse: 0.1841 - val_accuracy: 0.8000 - val_loss: 0.1994 - val_mse: 0.1994
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7541 - loss: 0.1914 - mse: 0.1914 - val_accuracy: 0.7600 - val_loss: 0.1997 - val_mse: 0.1997
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7402 - loss: 0.1941 - mse: 0.1941 - val_accuracy: 0.7600 - val_loss: 0.1997 - val_mse: 0.1997
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6979 - loss: 0.1906 - mse: 0.1906 - val_accuracy: 0.7600 - val_loss: 0.1995 - val_mse: 0.1995
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7090 - loss: 0.2027 - mse: 0.2027 - val_accuracy: 0.7600 - val_loss: 0.2006 - val_mse: 0.2006
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7021 - loss: 0.2052 - mse: 0.2052 - val_accuracy: 0.7600 - val_loss: 0.2002 - val_mse: 0.2002
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7396 - loss: 0.1802 - mse: 0.1802 - val_accuracy: 0.7600 - val_loss: 0.1997 - val_mse: 0.1997
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7548 - loss: 0.1948 - mse: 0.1948 - val_accuracy: 0.8000 - val_loss: 0.1983 - val_mse: 0.1983
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7221 - loss: 0.1938 - mse: 0.1938 - val_accuracy: 0.8000 - val_loss: 0.1982 - val_mse: 0.1982
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7512 - loss: 0.1991 - mse: 0.1991 - val_accuracy: 0.8000 - val_loss: 0.1984 - val_mse: 0.1984
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7798 - loss: 0.1738 - mse: 0.1738 - val_accuracy: 0.8000 - val_loss: 0.1988 - val_mse: 0.1988
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7035 - loss: 0.2006 - mse: 0.2006 - val_accuracy: 0.8000 - val_loss: 0.1986 - val_mse: 0.1986
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7257 - loss: 0.1878 - mse: 0.1878 - val_accuracy: 0.8000 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7562 - loss: 0.2023 - mse: 0.2023 - val_accuracy: 0.8000 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7964 - loss: 0.1907 - mse: 0.1907 - val_accuracy: 0.8000 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7144 - loss: 0.2045 - mse: 0.2045 - val_accuracy: 0.8000 - val_loss: 0.1979 - val_mse: 0.1979
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7457 - loss: 0.1884 - mse: 0.1884 - val_accuracy: 0.8000 - val_loss: 0.1970 - val_mse: 0.1970
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7547 - loss: 0.1870 - mse: 0.1870 - val_accuracy: 0.8000 - val_loss: 0.1966 - val_mse: 0.1966
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7561 - loss: 0.1914 - mse: 0.1914 - val_accuracy: 0.8000 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7270 - loss: 0.2018 - mse: 0.2018 - val_accuracy: 0.8000 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7464 - loss: 0.1927 - mse: 0.1927 - val_accuracy: 0.8000 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7637 - loss: 0.1872 - mse: 0.1872 - val_accuracy: 0.8000 - val_loss: 0.1965 - val_mse: 0.1965
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7569 - loss: 0.1863 - mse: 0.1863 - val_accuracy: 0.8000 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7804 - loss: 0.1810 - mse: 0.1810 - val_accuracy: 0.8000 - val_loss: 0.1969 - val_mse: 0.1969
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7491 - loss: 0.1913 - mse: 0.1913 - val_accuracy: 0.8000 - val_loss: 0.1965 - val_mse: 0.1965
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7582 - loss: 0.1885 - mse: 0.1885 - val_accuracy: 0.8000 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6875 - loss: 0.2011 - mse: 0.2011 - val_accuracy: 0.8000 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7277 - loss: 0.1921 - mse: 0.1921 - val_accuracy: 0.8000 - val_loss: 0.1979 - val_mse: 0.1979
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7312 - loss: 0.2000 - mse: 0.2000 - val_accuracy: 0.8000 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7208 - loss: 0.1863 - mse: 0.1863 - val_accuracy: 0.8000 - val_loss: 0.1957 - val_mse: 0.1957
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6992 - loss: 0.2012 - mse: 0.2012 - val_accuracy: 0.8000 - val_loss: 0.1956 - val_mse: 0.1956
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7095 - loss: 0.2010 - mse: 0.2010 - val_accuracy: 0.8000 - val_loss: 0.1962 - val_mse: 0.1962
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7291 - loss: 0.1949 - mse: 0.1949 - val_accuracy: 0.8000 - val_loss: 0.1962 - val_mse: 0.1962
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7596 - loss: 0.1783 - mse: 0.1783 - val_accuracy: 0.8000 - val_loss: 0.1949 - val_mse: 0.1949
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7442 - loss: 0.1854 - mse: 0.1854 - val_accuracy: 0.8000 - val_loss: 0.1944 - val_mse: 0.1944
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7942 - loss: 0.1771 - mse: 0.1771 - val_accuracy: 0.8000 - val_loss: 0.1939 - val_mse: 0.1939
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7463 - loss: 0.1926 - mse: 0.1926 - val_accuracy: 0.8000 - val_loss: 0.1946 - val_mse: 0.1946
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7622 - loss: 0.1925 - mse: 0.1925 - val_accuracy: 0.8000 - val_loss: 0.1956 - val_mse: 0.1956
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7068 - loss: 0.1966 - mse: 0.1966 - val_accuracy: 0.8000 - val_loss: 0.1956 - val_mse: 0.1956
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7707 - loss: 0.1905 - mse: 0.1905 - val_accuracy: 0.8000 - val_loss: 0.1954 - val_mse: 0.1954
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7047 - loss: 0.1925 - mse: 0.1925 - val_accuracy: 0.8000 - val_loss: 0.1952 - val_mse: 0.1952
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7221 - loss: 0.1886 - mse: 0.1886 - val_accuracy: 0.8000 - val_loss: 0.1951 - val_mse: 0.1951
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7082 - loss: 0.1996 - mse: 0.1996 - val_accuracy: 0.8000 - val_loss: 0.1943 - val_mse: 0.1943
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7727 - loss: 0.1866 - mse: 0.1866 - val_accuracy: 0.8000 - val_loss: 0.1943 - val_mse: 0.1943
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7761 - loss: 0.1812 - mse: 0.1812 - val_accuracy: 0.8000 - val_loss: 0.1949 - val_mse: 0.1949
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7734 - loss: 0.1822 - mse: 0.1822 - val_accuracy: 0.8000 - val_loss: 0.1939 - val_mse: 0.1939
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7371 - loss: 0.1986 - mse: 0.1986 - val_accuracy: 0.8000 - val_loss: 0.1936 - val_mse: 0.1936
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7574 - loss: 0.1906 - mse: 0.1906 - val_accuracy: 0.8000 - val_loss: 0.1942 - val_mse: 0.1942
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7588 - loss: 0.1939 - mse: 0.1939 - val_accuracy: 0.8000 - val_loss: 0.1935 - val_mse: 0.1935
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8018 - loss: 0.1808 - mse: 0.1808 - val_accuracy: 0.8000 - val_loss: 0.1924 - val_mse: 0.1924
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 48
#      45 plt.show()
#      47 tr_accuracy = min(history.history['accuracy'])
# ---> 48 ts_accuracy = min(history.history['val_acc'])
#      49 tr_mse = min(history.history['mse'])
#      50 ts_mse = min(history.history['val_mse'])
#
# KeyError: 'val_acc'
